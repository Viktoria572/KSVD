# %% [markdown]
# # Яременко Вікторія Лабораторна 3

# %% [markdown]
# 2.	Розробити звичайний автокодувальник для датасету MNIST на основі згорткової моделі.

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model

# Завантаження датасету MNIST
mnist = tf.keras.datasets.mnist
(x_train, _), (x_test, _) = mnist.load_data()

# Нормалізація даних та розширення розмірності для згорткових шарів
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))
x_test = np.reshape(x_test, (len(x_test), 28, 28, 1))

# Функція для створення згорткового автокодувальника
def build_conv_autoencoder():
    input_img = tf.keras.layers.Input(shape=(28, 28, 1))

    # Encoder
    encoded = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', padding='same')(input_img)
    encoded = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(encoded)
    encoded = tf.keras.layers.Conv2D(8, (3, 3), activation='relu', padding='same')(encoded)
    encoded = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(encoded)
    encoded = tf.keras.layers.Conv2D(8, (3, 3), activation='relu', padding='same')(encoded)
    encoded = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(encoded)

    # Decoder
    decoded = tf.keras.layers.Conv2D(8, (3, 3), activation='relu', padding='same')(encoded)
    decoded = tf.keras.layers.UpSampling2D((2, 2))(decoded)
    decoded = tf.keras.layers.Conv2D(8, (3, 3), activation='relu', padding='same')(decoded)
    decoded = tf.keras.layers.UpSampling2D((2, 2))(decoded)
    decoded = tf.keras.layers.Conv2D(16, (3, 3), activation='relu')(decoded)
    decoded = tf.keras.layers.UpSampling2D((2, 2))(decoded)
    decoded = tf.keras.layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(decoded)

    # Combine Encoder and Decoder layers
    autoencoder = tf.keras.models.Model(input_img, decoded)

    return autoencoder

# Побудова моделі
conv_autoencoder = build_conv_autoencoder()
conv_autoencoder.summary()

# Компіляція моделі
conv_autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# Навчання моделі
history = conv_autoencoder.fit(x_train, x_train,
                                epochs=20,
                                batch_size=128,
                                shuffle=True,
                                validation_data=(x_test, x_test))

# Візуалізація функції втрат
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Результати реконструкції
decoded_imgs = conv_autoencoder.predict(x_test)

# Відображення оригінальних та відтворених зображень
n = 10  # Кількість зображень для відображення
plt.figure(figsize=(20, 4))
for i in range(n):
    # Оригінальне зображення
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28), cmap='gray')
    plt.title('Original')
    plt.axis('off')

    # Відтворене зображення
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28), cmap='gray')
    plt.title('Reconstructed')
    plt.axis('off')
plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d (Conv2D)             (None, 28, 28, 16)        160
#
#  max_pooling2d (MaxPooling2  (None, 14, 14, 16)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 8)         1160
#
#  max_pooling2d_1 (MaxPoolin  (None, 7, 7, 8)           0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 7, 7, 8)           584
#
#  max_pooling2d_2 (MaxPoolin  (None, 4, 4, 8)           0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 4, 4, 8)           584
#
#  up_sampling2d (UpSampling2  (None, 8, 8, 8)           0
#  D)
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 8)           584
#
#  up_sampling2d_1 (UpSamplin  (None, 16, 16, 8)         0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 14, 14, 16)        1168
#
#  up_sampling2d_2 (UpSamplin  (None, 28, 28, 16)        0
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 28, 28, 1)         145
#
# =================================================================
# Total params: 4385 (17.13 KB)
# Trainable params: 4385 (17.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 469/469 [==============================] - 76s 147ms/step - loss: 0.2125 - val_loss: 0.1456
# Epoch 2/20
# 469/469 [==============================] - 62s 133ms/step - loss: 0.1360 - val_loss: 0.1271
# Epoch 3/20
# 469/469 [==============================] - 59s 125ms/step - loss: 0.1237 - val_loss: 0.1189
# Epoch 4/20
# 469/469 [==============================] - 60s 128ms/step - loss: 0.1179 - val_loss: 0.1144
# Epoch 5/20
# 469/469 [==============================] - 61s 130ms/step - loss: 0.1142 - val_loss: 0.1121
# Epoch 6/20
# 469/469 [==============================] - 60s 127ms/step - loss: 0.1117 - val_loss: 0.1092
# Epoch 7/20
# 469/469 [==============================] - 59s 125ms/step - loss: 0.1095 - val_loss: 0.1073
# Epoch 8/20
# 469/469 [==============================] - 60s 127ms/step - loss: 0.1079 - val_loss: 0.1059
# Epoch 9/20
# 469/469 [==============================] - 62s 131ms/step - loss: 0.1065 - val_loss: 0.1047
# Epoch 10/20
# 469/469 [==============================] - 60s 129ms/step - loss: 0.1054 - val_loss: 0.1047
# Epoch 11/20
# 469/469 [==============================] - 59s 125ms/step - loss: 0.1045 - val_loss: 0.1032
# Epoch 12/20
# 469/469 [==============================] - 61s 129ms/step - loss: 0.1037 - val_loss: 0.1025
# Epoch 13/20
# 469/469 [==============================] - 60s 128ms/step - loss: 0.1030 - val_loss: 0.1014
# Epoch 14/20
# 469/469 [==============================] - 62s 132ms/step - loss: 0.1024 - val_loss: 0.1011
# Epoch 15/20
# 469/469 [==============================] - 59s 126ms/step - loss: 0.1019 - val_loss: 0.1008
# Epoch 16/20
# 469/469 [==============================] - 61s 130ms/step - loss: 0.1014 - val_loss: 0.0997
# Epoch 17/20
# 469/469 [==============================] - 60s 129ms/step - loss: 0.1009 - val_loss: 0.0994
# Epoch 18/20
# 469/469 [==============================] - 61s 130ms/step - loss: 0.1004 - val_loss: 0.0989
# Epoch 19/20
# 469/469 [==============================] - 61s 131ms/step - loss: 0.1001 - val_loss: 0.0987
# Epoch 20/20
# 469/469 [==============================] - 63s 134ms/step - loss: 0.0997 - val_loss: 0.0984
# 313/313 [==============================] - 3s 10ms/step

# %%
# Функція для побудови графіка розподілу представлень
def plot_latent_space(encoder, x_test):
    # За допомогою енкодера отримуємо представлення для тестового набору даних
    encoded_imgs = encoder.predict(x_test)

    # Побудова графіка розподілу представлень
    plt.figure(figsize=(10, 8))
    plt.scatter(encoded_imgs[:, :, :, 0], encoded_imgs[:, :, :, 0], c='b', cmap='rainbow')  # Використовуємо один канал
    plt.colorbar()
    plt.xlabel('Latent Feature')
    plt.ylabel('Latent Feature')
    plt.title('Latent Space Representation')
    plt.show()

# Отримання енкодера з моделі автокодувальника
encoder = Model(inputs=conv_autoencoder.input, outputs=conv_autoencoder.get_layer('conv2d_6').output)

# Виклик функції для побудови графіка розподілу представлень
plot_latent_space(encoder, x_test)
# Out:
# 313/313 [==============================] - 5s 14ms/step
# <ipython-input-5-29edb28fefb7>:11: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(encoded_imgs[:, :, :, 0], encoded_imgs[:, :, :, 0], c='b', cmap='rainbow')  # Використовуємо один канал

# %% [markdown]
# Висновок: Для другого завдання я створила згортковий автокодувальник для датасету MNIST. Модель складалася з енкодера та декодера, які використовували згорткові та зворотні згорткові шари з функцією активації ReLU. Після навчання протягом 20 епох я візуалізувала графіки функції втрат, які показали зменшення втрат з кожною епохою. Модель ефективно відтворювала рукописні цифри з високою точністю. Також я побудувала графік розподілу представлень у latent space для подальшого аналізу. В цілому, згортковий автокодувальник демонстрував успішну реконструкцію зображень та зберігання структурної інформації у latent space.
